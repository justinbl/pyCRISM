# %%
import pyCRISM as pc
from matplotlib import pyplot as plt
input_file = '/Users/yebinlong/Library/CloudStorage/Dropbox/Projects/pyCAT/data/hrl00016cfe_07_if181l_trr3.img'

# %%
hrl16cfe = pc.CRISMdata(input_file)
hrl16cfe
# Out:
# pyCRISM_Version: 1.0
# File Name: HRL00016CFE_07_IF181L_TRR3
# Size (Y, X, L): (420, 320, 438)
# Solar Longitude: 56.278298
# Wavelength File: CDR490947778566_WA0100000L_3.IMG
# Distance to Mars: 1.6602818430451007 AU
# Channel: L
# Pixel Averaging Width: 2
# Observation Name: HRL00016CFE
# Start Time: 2010-02-25T04:03:20.126
# Detector Temperature: -148.366
# Photometric Correction: False
# Atmospheric Correction: False
# Resampled: False

# %%
# loading CRISM Data
hrl16cfe.load()
plt.imshow(hrl16cfe.ifdat[:,:,100],cmap='gray')
plt.colorbar()

# %%
plt.plot(hrl16cfe.meanwvl,hrl16cfe.ifdat[100,100,:])
plt.xlim([1,4.0])
# Out:
# (1.0, 4.0)

# %%
# photometric correction and atmospheric correction
hrl16cfe.crism_corr()
#hrl16cfe.crism_corr_save()
# Out:
# <> Photometric Correction Processing
# <> Atmospheric Correction Processing
# <> Correction Finished

# %%
plt.imshow(hrl16cfe.ifdat_corr[:,:,100],cmap='gray')
plt.colorbar()

# %%
plt.plot(hrl16cfe.meanwvl,hrl16cfe.ifdat_corr[100,100,:])
plt.xlim([1,4.0])
# Out:
# (1.0, 4.0)

# %%
# output CRISM project corr data
hrl16cfe.project_crism()

# %%
hrl16cfe.summaryproduct()
#hrl16cfe.project_summaryproduct()

# %%
plt.imshow(hrl16cfe.MIN2200(),cmap='jet',vmin=0,vmax=0.05)
plt.colorbar()

# %%
plt.imshow(hrl16cfe.BD2210(),cmap='jet',vmin=0,vmax=0.05)
plt.colorbar()
